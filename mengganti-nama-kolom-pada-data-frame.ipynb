# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.0.3

# %%
df = pd.read_csv('/kaggle/input/titanic/gender_submission.csv')

df_backup = df.copy(deep=True)

df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#diubah menggunakan lowercase untuk nama kolom dan mengganti spasi dengan _

df.columns = df.columns.str.replace(' ','_').str.lower()
df.head()
# Out:
#    passengerid  survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#diubah menggunakan lowercase untuk nama kolom dan mengganti spasi dengan _

df.columns = df.columns.str.replace(' ','_').str.lower()
df.head()
# Out:
#    passengerid  survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
